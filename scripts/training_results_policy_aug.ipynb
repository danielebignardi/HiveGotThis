# %% [markdown]
# # Training di value + policy head su Kaggle (imitazione dal dataset BoardSpace)
#
# Gemello di `train_colab.ipynb` per Kaggle Notebooks, aggiornato al dataset
# **policy** (`boardspace_policy_<anno>.jsonl`): ogni posizione porta anche le
# mosse legali con move features e target pi (1 sulla mossa umana). Si allena
# DA ZERO, con le due teste insieme: MSE del value + cross-entropy della
# policy (`--policy-weight`). A fine training il value deve tornare ai livelli
# della gen-0 (val MSE ~0,68, segno corretto ~72%): e' il controllo che il
# multi-task non lo ha danneggiato.
# Produce **solo il checkpoint dei pesi**: l'export TorchScript per il C++ va
# fatto in locale (`torch_geometric==2.6.1`), vedi `docs/spiegazione_value_network.md` §6.
#
# ### Prima di eseguire
#
# 1. **Account Kaggle verificato** (numero di telefono): serve per GPU e Internet.
# 2. **Crea un Dataset Kaggle privato** (*Datasets → New Dataset*) con tre file:
#    `hive_value_gnn.py`, `train_hive_value_gnn.py` (versioni correnti dal repo)
#    e `boardspace_policy_jsonl.zip`.
#    NB: Kaggle **scompatta da solo** gli zip caricati — nel Dataset compariranno
#    direttamente i `boardspace_policy_<anno>.jsonl` (47 GB scompattati: il
#    limite per Dataset e' 200 GB, ci stanno).
# 3. **Nuovo Notebook** (*Code → New Notebook*), poi importa questo file
#    (*File → Import Notebook*) e nel pannello di destra:
#    - *Input → Add Input*: collega il dataset creato al passo 2;
#    - *Session options → Accelerator*: **GPU T4 x2** (o P100);
#    - *Session options → Internet*: **ON** (serve per `pip install`).
# 4. Esegui le celle in ordine. Per un run non presidiato usa *Save Version →
#    Save & Run All*: esegue tutto in background e conserva l'output anche se
#    il browser si chiude (la sessione interattiva invece muore con lui).
#
# Rispetto al primo run policy (29 luglio: --sample 0.5, val MSE 0.705,
# policy CE 2.84) questo allena sul dataset INTERO con augmentation D6:
# il trainer ora carica i tensori in float16 e impacchetta le partite in
# Batch PyG (~13,5 GB in RAM sui ~29 disponibili, niente --sample), e con
# `--augment` ogni posizione riceve a ogni epoca una delle 12 simmetrie
# della board esagonale (rotazioni e riflessioni: informazione vera che la
# rete non puo' dedurre da sola). La validation resta non aumentata, quindi
# le metriche sono confrontabili col run precedente.
# La quota gratuita e' 30 ore di GPU a settimana.

# %%
# Trova script e dati nel Dataset collegato come Input, a qualunque
# profondita'. NB: Kaggle scompatta da solo gli zip caricati, quindi di
# norma i .jsonl sono gia' estratti (e lo zip non esiste piu').
import glob

def find_one(name):
    hits = glob.glob(f'/kaggle/input/**/{name}', recursive=True)
    return hits[0] if hits else None

TRAIN_PY = find_one('train_hive_value_gnn.py')
MODEL_PY = find_one('hive_value_gnn.py')
assert TRAIN_PY and MODEL_PY, 'script .py non trovati: collega il Dataset dal pannello Input'

INPUT_JSONL = sorted(glob.glob('/kaggle/input/**/boardspace_policy_*.jsonl', recursive=True))
ZIP = find_one('boardspace_policy_jsonl.zip')
assert INPUT_JSONL or ZIP, 'nessun boardspace_policy_*.jsonl e nessuno zip nel Dataset collegato'

CHECKPOINT = '/kaggle/working/checkpoint_gen0_policy_aug.pt'
print(f"{len(INPUT_JSONL)} jsonl gia' estratti" if INPUT_JSONL else f'zip da scompattare: {ZIP}')
# Out:
# 14 jsonl gia' estratti

# %%
# Verifica GPU e installa PyTorch Geometric.
# NB: qui la versione di torch_geometric e' libera perche' si fa solo training;
# il pin ==2.6.1 riguarda solo l'export TorchScript, che si fa in locale.
import torch
print('GPU disponibile:', torch.cuda.is_available(),
      '-', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'attiva la GPU nelle Session options!')

# %pip install -q torch_geometric
# Out:
# GPU disponibile: True - Tesla T4
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.5 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.

# %%
# Copia gli script in /kaggle/working e prepara la lista dei file dati.
# Se i .jsonl sono gia' estratti nell'input si leggono da li' (read-only va
# bene); se invece c'e' ancora lo zip, si scompatta su disco effimero
# (/kaggle/tmp): NON in /kaggle/working, altrimenti i 47 GB di JSONL
# finirebbero salvati come output del notebook a ogni versione.
import subprocess

subprocess.run(['cp', TRAIN_PY, MODEL_PY, '/kaggle/working/'], check=True)

if INPUT_JSONL:
    DATA_FILES = INPUT_JSONL
else:
    # !mkdir -p /kaggle/tmp/dataset && unzip -o -q "{ZIP}" -d /kaggle/tmp/dataset
    DATA_FILES = sorted(glob.glob('/kaggle/tmp/dataset/**/*.jsonl', recursive=True))

print(len(DATA_FILES), 'file jsonl:')
for f in DATA_FILES:
    print(' ', f)
# Out:
# 14 file jsonl:
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2013.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2014.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2015.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2016.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2017.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2018.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2019.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2020.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2021.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2022.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2023.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2024.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2025.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2026.jsonl

# %%
# Training value + policy DA ZERO sul dataset INTERO, con augmentation D6.
# Niente --sample: con float16 + partite impacchettate il dataset completo
# occupa ~13,5 GB sui ~29 disponibili. Se la RAM soffrisse comunque,
# aggiungere --sample 0.8.
# --max-hours 10.5: cintura di sicurezza sul limite di sessione Kaggle
# (12h, oltre le quali l'output della versione va PERSO) - il training si
# ferma prima di un'epoca che sforerebbe, con il best checkpoint salvo.
# 18 epoche: il run interrotto era al plateau gia' a meta' corsa, e il
# cosine comprime il decadimento sulle epoche disponibili (T_max=--epochs):
# stesso lr finale, meno ore di GPU. Col cosine il best tende ad arrivare
# nelle ULTIME epoche (lr basso che rifinisce): e' normale, non un segnale
# che servivano piu' epoche.
# --lr-schedule cosine: il run interrotto mostrava la validation che
# OSCILLAVA dopo l'epoca ~15 (lr costante troppo alto vicino al minimo);
# il decadimento coseno (da 1e-3 a 1e-4) stabilizza le epoche finali.
# Lettura dei log: riferimenti da battere - run 29 luglio (--sample 0.5):
# val MSE 0.705, CE 2.84; run interrotto (intero+augment, epoca 15):
# val MSE 0.685, CE 2.827. L'obiettivo e' scendere
# sotto entrambi; la CE parte da ~4,1 (uniforme su ~60 mosse legali).
files = ' '.join(DATA_FILES)

# !cd /kaggle/working && python -u train_hive_value_gnn.py {files} \
    --output "{CHECKPOINT}" \
    --policy-weight 1.0 --augment --lr-schedule cosine \
    --max-hours 10.5 \
    --device cuda --batch-size 256 --epochs 18
# Out:
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2013.jsonl: 131068 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2014.jsonl: 59869 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2015.jsonl: 41124 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2016.jsonl: 18176 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2017.jsonl: 53789 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2018.jsonl: 85524 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2019.jsonl: 74904 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2020.jsonl: 136242 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2021.jsonl: 147262 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2022.jsonl: 183817 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2023.jsonl: 257547 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2024.jsonl: 241282 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2025.jsonl: 114890 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2026.jsonl: 37470 posizioni
# Dataset: 31132 partite, 1582964 posizioni (1459706 decisive) -> train 1424803, validation 158161
# /usr/local/lib/python3.12/dist-packages/torch_geometric/utils/_scatter.py:91: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(
#   epoch 1: batch 556/5566  value MSE parziale 0.8054  (1038 posizioni/s)
#   epoch 1: batch 1112/5566  value MSE parziale 0.7728  (1044 posizioni/s)
#   epoch 1: batch 1668/5566  value MSE parziale 0.7584  (1044 posizioni/s)
#   epoch 1: batch 2224/5566  value MSE parziale 0.7492  (1046 posizioni/s)
#   epoch 1: batch 2780/5566  value MSE parziale 0.7427  (1049 posizioni/s)
#   epoch 1: batch 3336/5566  value MSE parziale 0.7372  (1047 posizioni/s)
#   epoch 1: batch 3892/5566  value MSE parziale 0.7334  (1049 posizioni/s)
#   epoch 1: batch 4448/5566  value MSE parziale 0.7300  (1050 posizioni/s)
#   epoch 1: batch 5004/5566  value MSE parziale 0.7269  (1050 posizioni/s)
#   epoch 1: batch 5560/5566  value MSE parziale 0.7244  (1049 posizioni/s)
# epoch   1  train MSE 0.7243  train policy CE 3.1580  train loss 3.8823  val MSE 0.7049  val segno-ok 70.9% (su 144601 decisive)  val policy CE 2.9974  [salvato]  lr 1.00e-03
#   epoch 2: batch 556/5566  value MSE parziale 0.6984  (1050 posizioni/s)
#   epoch 2: batch 1112/5566  value MSE parziale 0.6968  (1056 posizioni/s)
#   epoch 2: batch 1668/5566  value MSE parziale 0.6970  (1054 posizioni/s)
#   epoch 2: batch 2224/5566  value MSE parziale 0.6961  (1052 posizioni/s)
#   epoch 2: batch 2780/5566  value MSE parziale 0.6962  (1055 posizioni/s)
#   epoch 2: batch 3336/5566  value MSE parziale 0.6950  (1056 posizioni/s)
#   epoch 2: batch 3892/5566  value MSE parziale 0.6945  (1054 posizioni/s)
#   epoch 2: batch 4448/5566  value MSE parziale 0.6942  (1053 posizioni/s)
#   epoch 2: batch 5004/5566  value MSE parziale 0.6936  (1052 posizioni/s)
#   epoch 2: batch 5560/5566  value MSE parziale 0.6933  (1053 posizioni/s)
# epoch   2  train MSE 0.6933  train policy CE 3.0267  train loss 3.7200  val MSE 0.6947  val segno-ok 71.3% (su 144601 decisive)  val policy CE 2.9383  [salvato]  lr 9.93e-04
#   epoch 3: batch 556/5566  value MSE parziale 0.6870  (1067 posizioni/s)
#   epoch 3: batch 1112/5566  value MSE parziale 0.6844  (1061 posizioni/s)
#   epoch 3: batch 1668/5566  value MSE parziale 0.6838  (1064 posizioni/s)
#   epoch 3: batch 2224/5566  value MSE parziale 0.6841  (1062 posizioni/s)
#   epoch 3: batch 2780/5566  value MSE parziale 0.6839  (1059 posizioni/s)
#   epoch 3: batch 3336/5566  value MSE parziale 0.6832  (1060 posizioni/s)
#   epoch 3: batch 3892/5566  value MSE parziale 0.6834  (1063 posizioni/s)
#   epoch 3: batch 4448/5566  value MSE parziale 0.6829  (1066 posizioni/s)
#   epoch 3: batch 5004/5566  value MSE parziale 0.6828  (1064 posizioni/s)
#   epoch 3: batch 5560/5566  value MSE parziale 0.6826  (1063 posizioni/s)
# epoch   3  train MSE 0.6826  train policy CE 2.9878  train loss 3.6704  val MSE 0.6877  val segno-ok 71.6% (su 144601 decisive)  val policy CE 2.9103  [salvato]  lr 9.73e-04
#   epoch 4: batch 556/5566  value MSE parziale 0.6764  (1061 posizioni/s)
#   epoch 4: batch 1112/5566  value MSE parziale 0.6756  (1059 posizioni/s)
#   epoch 4: batch 1668/5566  value MSE parziale 0.6746  (1051 posizioni/s)
#   epoch 4: batch 2224/5566  value MSE parziale 0.6751  (1047 posizioni/s)
#   epoch 4: batch 2780/5566  value MSE parziale 0.6754  (1048 posizioni/s)
#   epoch 4: batch 3336/5566  value MSE parziale 0.6747  (1052 posizioni/s)
#   epoch 4: batch 3892/5566  value MSE parziale 0.6752  (1054 posizioni/s)
#   epoch 4: batch 4448/5566  value MSE parziale 0.6754  (1056 posizioni/s)
#   epoch 4: batch 5004/5566  value MSE parziale 0.6756  (1056 posizioni/s)
#   epoch 4: batch 5560/5566  value MSE parziale 0.6757  (1055 posizioni/s)
# epoch   4  train MSE 0.6756  train policy CE 2.9633  train loss 3.6390  val MSE 0.6935  val segno-ok 71.5% (su 144601 decisive)  val policy CE 2.8925  [salvato]  lr 9.40e-04
#   epoch 5: batch 556/5566  value MSE parziale 0.6707  (1045 posizioni/s)
#   epoch 5: batch 1112/5566  value MSE parziale 0.6707  (1046 posizioni/s)
#   epoch 5: batch 1668/5566  value MSE parziale 0.6713  (1047 posizioni/s)
#   epoch 5: batch 2224/5566  value MSE parziale 0.6703  (1044 posizioni/s)
#   epoch 5: batch 2780/5566  value MSE parziale 0.6700  (1047 posizioni/s)
#   epoch 5: batch 3336/5566  value MSE parziale 0.6712  (1050 posizioni/s)
#   epoch 5: batch 3892/5566  value MSE parziale 0.6709  (1053 posizioni/s)
#   epoch 5: batch 4448/5566  value MSE parziale 0.6705  (1053 posizioni/s)
#   epoch 5: batch 5004/5566  value MSE parziale 0.6705  (1051 posizioni/s)
#   epoch 5: batch 5560/5566  value MSE parziale 0.6702  (1050 posizioni/s)
# epoch   5  train MSE 0.6702  train policy CE 2.9456  train loss 3.6158  val MSE 0.6850  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8733  [salvato]  lr 8.95e-04
#   epoch 6: batch 556/5566  value MSE parziale 0.6644  (1035 posizioni/s)
#   epoch 6: batch 1112/5566  value MSE parziale 0.6664  (1041 posizioni/s)
#   epoch 6: batch 1668/5566  value MSE parziale 0.6659  (1038 posizioni/s)
#   epoch 6: batch 2224/5566  value MSE parziale 0.6660  (1035 posizioni/s)
#   epoch 6: batch 2780/5566  value MSE parziale 0.6649  (1033 posizioni/s)
#   epoch 6: batch 3336/5566  value MSE parziale 0.6652  (1033 posizioni/s)
#   epoch 6: batch 3892/5566  value MSE parziale 0.6655  (1031 posizioni/s)
#   epoch 6: batch 4448/5566  value MSE parziale 0.6653  (1032 posizioni/s)
#   epoch 6: batch 5004/5566  value MSE parziale 0.6653  (1031 posizioni/s)
#   epoch 6: batch 5560/5566  value MSE parziale 0.6650  (1031 posizioni/s)
# epoch   6  train MSE 0.6650  train policy CE 2.9329  train loss 3.5979  val MSE 0.6834  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8641  [salvato]  lr 8.39e-04
#   epoch 7: batch 556/5566  value MSE parziale 0.6612  (1040 posizioni/s)
#   epoch 7: batch 1112/5566  value MSE parziale 0.6600  (1044 posizioni/s)
#   epoch 7: batch 1668/5566  value MSE parziale 0.6603  (1041 posizioni/s)
#   epoch 7: batch 2224/5566  value MSE parziale 0.6604  (1040 posizioni/s)
#   epoch 7: batch 2780/5566  value MSE parziale 0.6602  (1039 posizioni/s)
#   epoch 7: batch 3336/5566  value MSE parziale 0.6603  (1040 posizioni/s)
#   epoch 7: batch 3892/5566  value MSE parziale 0.6602  (1041 posizioni/s)
#   epoch 7: batch 4448/5566  value MSE parziale 0.6602  (1042 posizioni/s)
#   epoch 7: batch 5004/5566  value MSE parziale 0.6607  (1043 posizioni/s)
#   epoch 7: batch 5560/5566  value MSE parziale 0.6607  (1046 posizioni/s)
# epoch   7  train MSE 0.6607  train policy CE 2.9226  train loss 3.5833  val MSE 0.6811  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8501  [salvato]  lr 7.75e-04
#   epoch 8: batch 556/5566  value MSE parziale 0.6601  (1022 posizioni/s)
#   epoch 8: batch 1112/5566  value MSE parziale 0.6571  (1024 posizioni/s)
#   epoch 8: batch 1668/5566  value MSE parziale 0.6573  (1028 posizioni/s)
#   epoch 8: batch 2224/5566  value MSE parziale 0.6570  (1038 posizioni/s)
#   epoch 8: batch 2780/5566  value MSE parziale 0.6568  (1045 posizioni/s)
#   epoch 8: batch 3336/5566  value MSE parziale 0.6561  (1048 posizioni/s)
#   epoch 8: batch 3892/5566  value MSE parziale 0.6561  (1047 posizioni/s)
#   epoch 8: batch 4448/5566  value MSE parziale 0.6563  (1045 posizioni/s)
#   epoch 8: batch 5004/5566  value MSE parziale 0.6558  (1043 posizioni/s)
#   epoch 8: batch 5560/5566  value MSE parziale 0.6559  (1045 posizioni/s)
# epoch   8  train MSE 0.6559  train policy CE 2.9132  train loss 3.5691  val MSE 0.6806  val segno-ok 72.0% (su 144601 decisive)  val policy CE 2.8471  [salvato]  lr 7.04e-04
#   epoch 9: batch 556/5566  value MSE parziale 0.6515  (1047 posizioni/s)
#   epoch 9: batch 1112/5566  value MSE parziale 0.6504  (1047 posizioni/s)
#   epoch 9: batch 1668/5566  value MSE parziale 0.6509  (1049 posizioni/s)
#   epoch 9: batch 2224/5566  value MSE parziale 0.6513  (1054 posizioni/s)
#   epoch 9: batch 2780/5566  value MSE parziale 0.6510  (1055 posizioni/s)
#   epoch 9: batch 3336/5566  value MSE parziale 0.6511  (1055 posizioni/s)
#   epoch 9: batch 3892/5566  value MSE parziale 0.6508  (1055 posizioni/s)
#   epoch 9: batch 4448/5566  value MSE parziale 0.6509  (1055 posizioni/s)
#   epoch 9: batch 5004/5566  value MSE parziale 0.6508  (1050 posizioni/s)
#   epoch 9: batch 5560/5566  value MSE parziale 0.6508  (1047 posizioni/s)
# epoch   9  train MSE 0.6508  train policy CE 2.9061  train loss 3.5569  val MSE 0.6835  val segno-ok 72.0% (su 144601 decisive)  val policy CE 2.8340  [salvato]  lr 6.28e-04
#   epoch 10: batch 556/5566  value MSE parziale 0.6457  (1020 posizioni/s)
#   epoch 10: batch 1112/5566  value MSE parziale 0.6465  (1025 posizioni/s)
#   epoch 10: batch 1668/5566  value MSE parziale 0.6467  (1027 posizioni/s)
#   epoch 10: batch 2224/5566  value MSE parziale 0.6466  (1026 posizioni/s)
#   epoch 10: batch 2780/5566  value MSE parziale 0.6462  (1026 posizioni/s)
#   epoch 10: batch 3336/5566  value MSE parziale 0.6454  (1024 posizioni/s)
#   epoch 10: batch 3892/5566  value MSE parziale 0.6454  (1027 posizioni/s)
#   epoch 10: batch 4448/5566  value MSE parziale 0.6462  (1027 posizioni/s)
#   epoch 10: batch 5004/5566  value MSE parziale 0.6460  (1026 posizioni/s)
#   epoch 10: batch 5560/5566  value MSE parziale 0.6460  (1027 posizioni/s)
# epoch  10  train MSE 0.6460  train policy CE 2.8995  train loss 3.5456  val MSE 0.6852  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8280  [salvato]  lr 5.50e-04
#   epoch 11: batch 556/5566  value MSE parziale 0.6397  (1046 posizioni/s)
#   epoch 11: batch 1112/5566  value MSE parziale 0.6397  (1047 posizioni/s)
#   epoch 11: batch 1668/5566  value MSE parziale 0.6400  (1050 posizioni/s)
#   epoch 11: batch 2224/5566  value MSE parziale 0.6406  (1053 posizioni/s)
#   epoch 11: batch 2780/5566  value MSE parziale 0.6407  (1058 posizioni/s)
#   epoch 11: batch 3336/5566  value MSE parziale 0.6409  (1061 posizioni/s)
#   epoch 11: batch 3892/5566  value MSE parziale 0.6411  (1056 posizioni/s)
#   epoch 11: batch 4448/5566  value MSE parziale 0.6409  (1044 posizioni/s)
#   epoch 11: batch 5004/5566  value MSE parziale 0.6409  (1034 posizioni/s)
#   epoch 11: batch 5560/5566  value MSE parziale 0.6413  (1029 posizioni/s)
# epoch  11  train MSE 0.6412  train policy CE 2.8924  train loss 3.5336  val MSE 0.6878  val segno-ok 71.6% (su 144601 decisive)  val policy CE 2.8306  lr 4.72e-04
#   epoch 12: batch 556/5566  value MSE parziale 0.6385  (949 posizioni/s)
#   epoch 12: batch 1112/5566  value MSE parziale 0.6357  (974 posizioni/s)
#   epoch 12: batch 1668/5566  value MSE parziale 0.6363  (986 posizioni/s)
#   epoch 12: batch 2224/5566  value MSE parziale 0.6362  (985 posizioni/s)
#   epoch 12: batch 2780/5566  value MSE parziale 0.6360  (977 posizioni/s)
#   epoch 12: batch 3336/5566  value MSE parziale 0.6364  (972 posizioni/s)
#   epoch 12: batch 3892/5566  value MSE parziale 0.6364  (969 posizioni/s)
#   epoch 12: batch 4448/5566  value MSE parziale 0.6366  (966 posizioni/s)
#   epoch 12: batch 5004/5566  value MSE parziale 0.6364  (968 posizioni/s)
#   epoch 12: batch 5560/5566  value MSE parziale 0.6368  (969 posizioni/s)
# epoch  12  train MSE 0.6368  train policy CE 2.8868  train loss 3.5236  val MSE 0.6834  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8239  [salvato]  lr 3.96e-04
#   epoch 13: batch 556/5566  value MSE parziale 0.6336  (981 posizioni/s)
#   epoch 13: batch 1112/5566  value MSE parziale 0.6329  (981 posizioni/s)
#   epoch 13: batch 1668/5566  value MSE parziale 0.6321  (980 posizioni/s)
#   epoch 13: batch 2224/5566  value MSE parziale 0.6319  (981 posizioni/s)
#   epoch 13: batch 2780/5566  value MSE parziale 0.6321  (980 posizioni/s)
#   epoch 13: batch 3336/5566  value MSE parziale 0.6316  (981 posizioni/s)
#   epoch 13: batch 3892/5566  value MSE parziale 0.6312  (981 posizioni/s)
#   epoch 13: batch 4448/5566  value MSE parziale 0.6314  (980 posizioni/s)
#   epoch 13: batch 5004/5566  value MSE parziale 0.6318  (980 posizioni/s)
#   epoch 13: batch 5560/5566  value MSE parziale 0.6320  (980 posizioni/s)
# epoch  13  train MSE 0.6320  train policy CE 2.8815  train loss 3.5135  val MSE 0.6842  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8172  [salvato]  lr 3.25e-04
#   epoch 14: batch 556/5566  value MSE parziale 0.6280  (977 posizioni/s)
#   epoch 14: batch 1112/5566  value MSE parziale 0.6287  (976 posizioni/s)
#   epoch 14: batch 1668/5566  value MSE parziale 0.6286  (974 posizioni/s)
#   epoch 14: batch 2224/5566  value MSE parziale 0.6297  (973 posizioni/s)
#   epoch 14: batch 2780/5566  value MSE parziale 0.6293  (974 posizioni/s)
#   epoch 14: batch 3336/5566  value MSE parziale 0.6282  (975 posizioni/s)
#   epoch 14: batch 3892/5566  value MSE parziale 0.6276  (974 posizioni/s)
#   epoch 14: batch 4448/5566  value MSE parziale 0.6275  (975 posizioni/s)
#   epoch 14: batch 5004/5566  value MSE parziale 0.6278  (975 posizioni/s)
#   epoch 14: batch 5560/5566  value MSE parziale 0.6278  (975 posizioni/s)
# epoch  14  train MSE 0.6278  train policy CE 2.8763  train loss 3.5041  val MSE 0.6890  val segno-ok 71.9% (su 144601 decisive)  val policy CE 2.8195  lr 2.61e-04
#   epoch 15: batch 556/5566  value MSE parziale 0.6207  (977 posizioni/s)
#   epoch 15: batch 1112/5566  value MSE parziale 0.6213  (977 posizioni/s)
#   epoch 15: batch 1668/5566  value MSE parziale 0.6224  (979 posizioni/s)
#   epoch 15: batch 2224/5566  value MSE parziale 0.6229  (979 posizioni/s)
#   epoch 15: batch 2780/5566  value MSE parziale 0.6232  (983 posizioni/s)
#   epoch 15: batch 3336/5566  value MSE parziale 0.6237  (988 posizioni/s)
#   epoch 15: batch 3892/5566  value MSE parziale 0.6237  (991 posizioni/s)
#   epoch 15: batch 4448/5566  value MSE parziale 0.6238  (994 posizioni/s)
#   epoch 15: batch 5004/5566  value MSE parziale 0.6240  (995 posizioni/s)
#   epoch 15: batch 5560/5566  value MSE parziale 0.6242  (1000 posizioni/s)
# epoch  15  train MSE 0.6242  train policy CE 2.8729  train loss 3.4970  val MSE 0.6887  val segno-ok 71.7% (su 144601 decisive)  val policy CE 2.8142  lr 2.05e-04
#   epoch 16: batch 556/5566  value MSE parziale 0.6209  (960 posizioni/s)
#   epoch 16: batch 1112/5566  value MSE parziale 0.6201  (952 posizioni/s)
#   epoch 16: batch 1668/5566  value MSE parziale 0.6204  (950 posizioni/s)
#   epoch 16: batch 2224/5566  value MSE parziale 0.6208  (957 posizioni/s)
#   epoch 16: batch 2780/5566  value MSE parziale 0.6205  (965 posizioni/s)
#   epoch 16: batch 3336/5566  value MSE parziale 0.6204  (971 posizioni/s)
#   epoch 16: batch 3892/5566  value MSE parziale 0.6209  (978 posizioni/s)
#   epoch 16: batch 4448/5566  value MSE parziale 0.6209  (984 posizioni/s)
#   epoch 16: batch 5004/5566  value MSE parziale 0.6211  (988 posizioni/s)
#   epoch 16: batch 5560/5566  value MSE parziale 0.6207  (991 posizioni/s)
# epoch  16  train MSE 0.6207  train policy CE 2.8703  train loss 3.4910  val MSE 0.6916  val segno-ok 71.7% (su 144601 decisive)  val policy CE 2.8138  lr 1.60e-04
#   epoch 17: batch 556/5566  value MSE parziale 0.6167  (1004 posizioni/s)
#   epoch 17: batch 1112/5566  value MSE parziale 0.6166  (1007 posizioni/s)
#   epoch 17: batch 1668/5566  value MSE parziale 0.6173  (1009 posizioni/s)
#   epoch 17: batch 2224/5566  value MSE parziale 0.6178  (1010 posizioni/s)
#   epoch 17: batch 2780/5566  value MSE parziale 0.6182  (1010 posizioni/s)
#   epoch 17: batch 3336/5566  value MSE parziale 0.6186  (1010 posizioni/s)
#   epoch 17: batch 3892/5566  value MSE parziale 0.6182  (1006 posizioni/s)
#   epoch 17: batch 4448/5566  value MSE parziale 0.6178  (998 posizioni/s)
#   epoch 17: batch 5004/5566  value MSE parziale 0.6178  (991 posizioni/s)
#   epoch 17: batch 5560/5566  value MSE parziale 0.6179  (987 posizioni/s)
# epoch  17  train MSE 0.6179  train policy CE 2.8670  train loss 3.4849  val MSE 0.6925  val segno-ok 71.7% (su 144601 decisive)  val policy CE 2.8130  lr 1.27e-04
#   epoch 18: batch 556/5566  value MSE parziale 0.6150  (957 posizioni/s)
#   epoch 18: batch 1112/5566  value MSE parziale 0.6163  (959 posizioni/s)
#   epoch 18: batch 1668/5566  value MSE parziale 0.6165  (961 posizioni/s)
#   epoch 18: batch 2224/5566  value MSE parziale 0.6165  (962 posizioni/s)
#   epoch 18: batch 2780/5566  value MSE parziale 0.6164  (961 posizioni/s)
#   epoch 18: batch 3336/5566  value MSE parziale 0.6167  (961 posizioni/s)
#   epoch 18: batch 3892/5566  value MSE parziale 0.6162  (960 posizioni/s)
#   epoch 18: batch 4448/5566  value MSE parziale 0.6162  (961 posizioni/s)
#   epoch 18: batch 5004/5566  value MSE parziale 0.6160  (961 posizioni/s)
#   epoch 18: batch 5560/5566  value MSE parziale 0.6159  (960 posizioni/s)
# epoch  18  train MSE 0.6159  train policy CE 2.8658  train loss 3.4817  val MSE 0.6933  val segno-ok 71.7% (su 144601 decisive)  val policy CE 2.8114  lr 1.07e-04
#
# Checkpoint migliore salvato in: /kaggle/working/checkpoint_gen0_policy_aug.pt (MSE 3.5013)
# Per esportarlo per il C++:
#   python3 scripts/export_hive_value_gnn.py --weights /kaggle/working/checkpoint_gen0_policy_aug.pt --output hive_value_gnn.pt

# %% [markdown]
# ### Dopo il training
#
# Il checkpoint migliore è in `/kaggle/working/checkpoint_gen0_policy_aug.pt`: si
# scarica dal file browser del pannello di destra (sessione interattiva) o
# dalla scheda *Output* del notebook (dopo *Save & Run All*). Conviene anche
# caricarlo nella cartella Drive `HiveGotThis_colab/`, dove stanno gli altri
# checkpoint. In locale:
#
# ```bash
# # esporta per il C++ (ambiente locale con torch_geometric==2.6.1)
# python3 scripts/export_hive_value_gnn.py --weights checkpoint_gen0_policy_aug.pt --output hive_policy_gen0.pt
#
# # il motore la usa (l'MCTS rileva la policy head e passa a PUCT da solo)
# ./build/HiveEngine hive_policy_gen0.pt
# ```
#
# I passi successivi sono il benchmark del costo PUCT (la policy aggiunge una
# chiamata alla rete per espansione) e il match dell'harness contro la gen-0
# value-only: stesso match, stesse condizioni, un modello per lato
# (`tools/uhp_match.py`, doc §8).
