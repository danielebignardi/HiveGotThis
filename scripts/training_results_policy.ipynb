# %% [markdown]
# # Training di value + policy head su Kaggle (imitazione dal dataset BoardSpace)
#
# Gemello di `train_colab.ipynb` per Kaggle Notebooks, aggiornato al dataset
# **policy** (`boardspace_policy_<anno>.jsonl`): ogni posizione porta anche le
# mosse legali con move features e target pi (1 sulla mossa umana). Si allena
# DA ZERO, con le due teste insieme: MSE del value + cross-entropy della
# policy (`--policy-weight`). A fine training il value deve tornare ai livelli
# della gen-0 (val MSE ~0,68, segno corretto ~72%): e' il controllo che il
# multi-task non lo ha danneggiato.
# Produce **solo il checkpoint dei pesi**: l'export TorchScript per il C++ va
# fatto in locale (`torch_geometric==2.6.1`), vedi `docs/spiegazione_value_network.md` §6.
#
# ### Prima di eseguire
#
# 1. **Account Kaggle verificato** (numero di telefono): serve per GPU e Internet.
# 2. **Crea un Dataset Kaggle privato** (*Datasets → New Dataset*) con tre file:
#    `hive_value_gnn.py`, `train_hive_value_gnn.py` (versioni correnti dal repo)
#    e `boardspace_policy_jsonl.zip`.
#    NB: Kaggle **scompatta da solo** gli zip caricati — nel Dataset compariranno
#    direttamente i `boardspace_policy_<anno>.jsonl` (47 GB scompattati: il
#    limite per Dataset e' 200 GB, ci stanno).
# 3. **Nuovo Notebook** (*Code → New Notebook*), poi importa questo file
#    (*File → Import Notebook*) e nel pannello di destra:
#    - *Input → Add Input*: collega il dataset creato al passo 2;
#    - *Session options → Accelerator*: **GPU T4 x2** (o P100);
#    - *Session options → Internet*: **ON** (serve per `pip install`).
# 4. Esegui le celle in ordine. Per un run non presidiato usa *Save Version →
#    Save & Run All*: esegue tutto in background e conserva l'output anche se
#    il browser si chiude (la sessione interattiva invece muore con lui).
#
# Il vincolo nuovo e' la RAM: con le move features (~60 mosse × 32 float a
# posizione) il dataset completo in memoria supera i ~29 GB della sessione,
# percio' il comando usa `--sample 0.5` (~790k posizioni, ~12 GB: comodo).
# Il sottocampionamento avviene DENTRO le partite, tutte restano rappresentate.
# La quota gratuita e' 30 ore di GPU a settimana.

# %%
# Trova script e dati nel Dataset collegato come Input, a qualunque
# profondita'. NB: Kaggle scompatta da solo gli zip caricati, quindi di
# norma i .jsonl sono gia' estratti (e lo zip non esiste piu').
import glob

def find_one(name):
    hits = glob.glob(f'/kaggle/input/**/{name}', recursive=True)
    return hits[0] if hits else None

TRAIN_PY = find_one('train_hive_value_gnn.py')
MODEL_PY = find_one('hive_value_gnn.py')
assert TRAIN_PY and MODEL_PY, 'script .py non trovati: collega il Dataset dal pannello Input'

INPUT_JSONL = sorted(glob.glob('/kaggle/input/**/boardspace_policy_*.jsonl', recursive=True))
ZIP = find_one('boardspace_policy_jsonl.zip')
assert INPUT_JSONL or ZIP, 'nessun boardspace_policy_*.jsonl e nessuno zip nel Dataset collegato'

CHECKPOINT = '/kaggle/working/checkpoint_gen0_policy.pt'
print(f"{len(INPUT_JSONL)} jsonl gia' estratti" if INPUT_JSONL else f'zip da scompattare: {ZIP}')
# Out:
# 14 jsonl gia' estratti

# %%
# Verifica GPU e installa PyTorch Geometric.
# NB: qui la versione di torch_geometric e' libera perche' si fa solo training;
# il pin ==2.6.1 riguarda solo l'export TorchScript, che si fa in locale.
import torch
print('GPU disponibile:', torch.cuda.is_available(),
      '-', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'attiva la GPU nelle Session options!')

# %pip install -q torch_geometric
# Out:
# GPU disponibile: True - Tesla T4
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.4 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.

# %%
# Copia gli script in /kaggle/working e prepara la lista dei file dati.
# Se i .jsonl sono gia' estratti nell'input si leggono da li' (read-only va
# bene); se invece c'e' ancora lo zip, si scompatta su disco effimero
# (/kaggle/tmp): NON in /kaggle/working, altrimenti i 47 GB di JSONL
# finirebbero salvati come output del notebook a ogni versione.
import subprocess

subprocess.run(['cp', TRAIN_PY, MODEL_PY, '/kaggle/working/'], check=True)

if INPUT_JSONL:
    DATA_FILES = INPUT_JSONL
else:
    # !mkdir -p /kaggle/tmp/dataset && unzip -o -q "{ZIP}" -d /kaggle/tmp/dataset
    DATA_FILES = sorted(glob.glob('/kaggle/tmp/dataset/**/*.jsonl', recursive=True))

print(len(DATA_FILES), 'file jsonl:')
for f in DATA_FILES:
    print(' ', f)
# Out:
# 14 file jsonl:
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2013.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2014.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2015.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2016.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2017.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2018.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2019.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2020.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2021.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2022.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2023.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2024.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2025.jsonl
#   /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2026.jsonl

# %%
# Training value + policy DA ZERO (nessun --init-weights).
# --sample 0.5: mezze posizioni (~790k), tutte le partite rappresentate —
# senza, il dataset policy non sta nei ~29 GB di RAM (le move features
# pesano ~4 volte il solo grafo). Se anche cosi' la RAM soffrisse,
# scendere a --sample 0.4.
# Lettura dei log: la cross-entropy di policy in validation parte da ~4,1
# (distribuzione uniforme su ~60 mosse legali medie) e deve scendere
# NETTAMENTE; il value MSE deve avvicinarsi a ~0,68 (il livello gen-0).
# python -u = output senza buffering: l'avanzamento compare in tempo reale.
files = ' '.join(DATA_FILES)

# !cd /kaggle/working && python -u train_hive_value_gnn.py {files} \
    --output "{CHECKPOINT}" \
    --policy-weight 1.0 --sample 0.5 \
    --device cuda --batch-size 256 --epochs 30
# Out:
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2013.jsonl: 65598 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2014.jsonl: 29732 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2015.jsonl: 20445 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2016.jsonl: 9032 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2017.jsonl: 26828 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2018.jsonl: 42780 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2019.jsonl: 37441 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2020.jsonl: 68183 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2021.jsonl: 73842 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2022.jsonl: 91971 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2023.jsonl: 128413 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2024.jsonl: 120733 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2025.jsonl: 57292 posizioni
#   caricato /kaggle/input/datasets/danielebignardi/data-and-scripts/boardspace_policy_jsonl/boardspace_policy_2026.jsonl: 18677 posizioni
# Dataset: 31132 partite, 790967 posizioni (729493 decisive) -> train 711866, validation 79101
# /usr/local/lib/python3.12/dist-packages/torch_geometric/utils/_scatter.py:91: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(
#   epoch 1: batch 278/2781  value MSE parziale 0.8529  (1353 posizioni/s)
#   epoch 1: batch 556/2781  value MSE parziale 0.8082  (1381 posizioni/s)
#   epoch 1: batch 834/2781  value MSE parziale 0.7878  (1388 posizioni/s)
#   epoch 1: batch 1112/2781  value MSE parziale 0.7754  (1397 posizioni/s)
#   epoch 1: batch 1390/2781  value MSE parziale 0.7660  (1404 posizioni/s)
#   epoch 1: batch 1668/2781  value MSE parziale 0.7592  (1404 posizioni/s)
#   epoch 1: batch 1946/2781  value MSE parziale 0.7536  (1405 posizioni/s)
#   epoch 1: batch 2224/2781  value MSE parziale 0.7489  (1407 posizioni/s)
#   epoch 1: batch 2502/2781  value MSE parziale 0.7451  (1410 posizioni/s)
#   epoch 1: batch 2780/2781  value MSE parziale 0.7424  (1413 posizioni/s)
# epoch   1  train MSE 0.7424  train policy CE 3.2291  train loss 3.9714  val MSE 0.7189  val segno-ok 69.9% (su 72236 decisive)  val policy CE 3.0551  [salvato]
#   epoch 2: batch 278/2781  value MSE parziale 0.7091  (1448 posizioni/s)
#   epoch 2: batch 556/2781  value MSE parziale 0.7092  (1443 posizioni/s)
#   epoch 2: batch 834/2781  value MSE parziale 0.7076  (1434 posizioni/s)
#   epoch 2: batch 1112/2781  value MSE parziale 0.7070  (1431 posizioni/s)
#   epoch 2: batch 1390/2781  value MSE parziale 0.7066  (1432 posizioni/s)
#   epoch 2: batch 1668/2781  value MSE parziale 0.7057  (1432 posizioni/s)
#   epoch 2: batch 1946/2781  value MSE parziale 0.7053  (1433 posizioni/s)
#   epoch 2: batch 2224/2781  value MSE parziale 0.7044  (1432 posizioni/s)
#   epoch 2: batch 2502/2781  value MSE parziale 0.7038  (1431 posizioni/s)
#   epoch 2: batch 2780/2781  value MSE parziale 0.7033  (1430 posizioni/s)
# epoch   2  train MSE 0.7033  train policy CE 3.0805  train loss 3.7838  val MSE 0.7047  val segno-ok 70.5% (su 72236 decisive)  val policy CE 2.9876  [salvato]
#   epoch 3: batch 278/2781  value MSE parziale 0.6938  (1435 posizioni/s)
#   epoch 3: batch 556/2781  value MSE parziale 0.6934  (1440 posizioni/s)
#   epoch 3: batch 834/2781  value MSE parziale 0.6940  (1439 posizioni/s)
#   epoch 3: batch 1112/2781  value MSE parziale 0.6944  (1434 posizioni/s)
#   epoch 3: batch 1390/2781  value MSE parziale 0.6940  (1427 posizioni/s)
#   epoch 3: batch 1668/2781  value MSE parziale 0.6934  (1423 posizioni/s)
#   epoch 3: batch 1946/2781  value MSE parziale 0.6930  (1417 posizioni/s)
#   epoch 3: batch 2224/2781  value MSE parziale 0.6925  (1414 posizioni/s)
#   epoch 3: batch 2502/2781  value MSE parziale 0.6922  (1415 posizioni/s)
#   epoch 3: batch 2780/2781  value MSE parziale 0.6925  (1415 posizioni/s)
# epoch   3  train MSE 0.6925  train policy CE 3.0364  train loss 3.7289  val MSE 0.6994  val segno-ok 70.6% (su 72236 decisive)  val policy CE 2.9651  [salvato]
#   epoch 4: batch 278/2781  value MSE parziale 0.6847  (1412 posizioni/s)
#   epoch 4: batch 556/2781  value MSE parziale 0.6835  (1420 posizioni/s)
#   epoch 4: batch 834/2781  value MSE parziale 0.6856  (1419 posizioni/s)
#   epoch 4: batch 1112/2781  value MSE parziale 0.6846  (1417 posizioni/s)
#   epoch 4: batch 1390/2781  value MSE parziale 0.6848  (1418 posizioni/s)
#   epoch 4: batch 1668/2781  value MSE parziale 0.6849  (1418 posizioni/s)
#   epoch 4: batch 1946/2781  value MSE parziale 0.6851  (1418 posizioni/s)
#   epoch 4: batch 2224/2781  value MSE parziale 0.6852  (1419 posizioni/s)
#   epoch 4: batch 2502/2781  value MSE parziale 0.6848  (1421 posizioni/s)
#   epoch 4: batch 2780/2781  value MSE parziale 0.6843  (1421 posizioni/s)
# epoch   4  train MSE 0.6843  train policy CE 3.0085  train loss 3.6928  val MSE 0.6923  val segno-ok 71.2% (su 72236 decisive)  val policy CE 2.9336  [salvato]
#   epoch 5: batch 278/2781  value MSE parziale 0.6812  (1422 posizioni/s)
#   epoch 5: batch 556/2781  value MSE parziale 0.6812  (1431 posizioni/s)
#   epoch 5: batch 834/2781  value MSE parziale 0.6799  (1431 posizioni/s)
#   epoch 5: batch 1112/2781  value MSE parziale 0.6791  (1427 posizioni/s)
#   epoch 5: batch 1390/2781  value MSE parziale 0.6792  (1427 posizioni/s)
#   epoch 5: batch 1668/2781  value MSE parziale 0.6787  (1425 posizioni/s)
#   epoch 5: batch 1946/2781  value MSE parziale 0.6783  (1425 posizioni/s)
#   epoch 5: batch 2224/2781  value MSE parziale 0.6787  (1422 posizioni/s)
#   epoch 5: batch 2502/2781  value MSE parziale 0.6785  (1419 posizioni/s)
#   epoch 5: batch 2780/2781  value MSE parziale 0.6787  (1417 posizioni/s)
# epoch   5  train MSE 0.6787  train policy CE 2.9902  train loss 3.6689  val MSE 0.6897  val segno-ok 71.4% (su 72236 decisive)  val policy CE 2.9181  [salvato]
#   epoch 6: batch 278/2781  value MSE parziale 0.6745  (1422 posizioni/s)
#   epoch 6: batch 556/2781  value MSE parziale 0.6742  (1418 posizioni/s)
#   epoch 6: batch 834/2781  value MSE parziale 0.6738  (1416 posizioni/s)
#   epoch 6: batch 1112/2781  value MSE parziale 0.6748  (1415 posizioni/s)
#   epoch 6: batch 1390/2781  value MSE parziale 0.6741  (1414 posizioni/s)
#   epoch 6: batch 1668/2781  value MSE parziale 0.6738  (1415 posizioni/s)
#   epoch 6: batch 1946/2781  value MSE parziale 0.6739  (1416 posizioni/s)
#   epoch 6: batch 2224/2781  value MSE parziale 0.6744  (1417 posizioni/s)
#   epoch 6: batch 2502/2781  value MSE parziale 0.6739  (1417 posizioni/s)
#   epoch 6: batch 2780/2781  value MSE parziale 0.6733  (1417 posizioni/s)
# epoch   6  train MSE 0.6733  train policy CE 2.9757  train loss 3.6490  val MSE 0.6892  val segno-ok 71.2% (su 72236 decisive)  val policy CE 2.9092  [salvato]
#   epoch 7: batch 278/2781  value MSE parziale 0.6694  (1413 posizioni/s)
#   epoch 7: batch 556/2781  value MSE parziale 0.6688  (1419 posizioni/s)
#   epoch 7: batch 834/2781  value MSE parziale 0.6672  (1420 posizioni/s)
#   epoch 7: batch 1112/2781  value MSE parziale 0.6685  (1424 posizioni/s)
#   epoch 7: batch 1390/2781  value MSE parziale 0.6680  (1426 posizioni/s)
#   epoch 7: batch 1668/2781  value MSE parziale 0.6687  (1428 posizioni/s)
#   epoch 7: batch 1946/2781  value MSE parziale 0.6690  (1428 posizioni/s)
#   epoch 7: batch 2224/2781  value MSE parziale 0.6689  (1425 posizioni/s)
#   epoch 7: batch 2502/2781  value MSE parziale 0.6687  (1424 posizioni/s)
#   epoch 7: batch 2780/2781  value MSE parziale 0.6686  (1424 posizioni/s)
# epoch   7  train MSE 0.6686  train policy CE 2.9638  train loss 3.6323  val MSE 0.6977  val segno-ok 71.0% (su 72236 decisive)  val policy CE 2.8986  [salvato]
#   epoch 8: batch 278/2781  value MSE parziale 0.6607  (1394 posizioni/s)
#   epoch 8: batch 556/2781  value MSE parziale 0.6637  (1399 posizioni/s)
#   epoch 8: batch 834/2781  value MSE parziale 0.6631  (1393 posizioni/s)
#   epoch 8: batch 1112/2781  value MSE parziale 0.6640  (1392 posizioni/s)
#   epoch 8: batch 1390/2781  value MSE parziale 0.6649  (1390 posizioni/s)
#   epoch 8: batch 1668/2781  value MSE parziale 0.6643  (1391 posizioni/s)
#   epoch 8: batch 1946/2781  value MSE parziale 0.6650  (1391 posizioni/s)
#   epoch 8: batch 2224/2781  value MSE parziale 0.6652  (1392 posizioni/s)
#   epoch 8: batch 2502/2781  value MSE parziale 0.6653  (1395 posizioni/s)
#   epoch 8: batch 2780/2781  value MSE parziale 0.6652  (1394 posizioni/s)
# epoch   8  train MSE 0.6652  train policy CE 2.9543  train loss 3.6195  val MSE 0.6863  val segno-ok 71.6% (su 72236 decisive)  val policy CE 2.8831  [salvato]
#   epoch 9: batch 278/2781  value MSE parziale 0.6578  (1389 posizioni/s)
#   epoch 9: batch 556/2781  value MSE parziale 0.6574  (1398 posizioni/s)
#   epoch 9: batch 834/2781  value MSE parziale 0.6596  (1394 posizioni/s)
#   epoch 9: batch 1112/2781  value MSE parziale 0.6610  (1397 posizioni/s)
#   epoch 9: batch 1390/2781  value MSE parziale 0.6623  (1394 posizioni/s)
#   epoch 9: batch 1668/2781  value MSE parziale 0.6624  (1397 posizioni/s)
#   epoch 9: batch 1946/2781  value MSE parziale 0.6617  (1399 posizioni/s)
#   epoch 9: batch 2224/2781  value MSE parziale 0.6613  (1398 posizioni/s)
#   epoch 9: batch 2502/2781  value MSE parziale 0.6616  (1399 posizioni/s)
#   epoch 9: batch 2780/2781  value MSE parziale 0.6616  (1398 posizioni/s)
# epoch   9  train MSE 0.6616  train policy CE 2.9456  train loss 3.6072  val MSE 0.6890  val segno-ok 71.5% (su 72236 decisive)  val policy CE 2.8822
#   epoch 10: batch 278/2781  value MSE parziale 0.6580  (1391 posizioni/s)
#   epoch 10: batch 556/2781  value MSE parziale 0.6578  (1390 posizioni/s)
#   epoch 10: batch 834/2781  value MSE parziale 0.6566  (1386 posizioni/s)
#   epoch 10: batch 1112/2781  value MSE parziale 0.6584  (1385 posizioni/s)
#   epoch 10: batch 1390/2781  value MSE parziale 0.6588  (1386 posizioni/s)
#   epoch 10: batch 1668/2781  value MSE parziale 0.6590  (1387 posizioni/s)
#   epoch 10: batch 1946/2781  value MSE parziale 0.6583  (1390 posizioni/s)
#   epoch 10: batch 2224/2781  value MSE parziale 0.6586  (1390 posizioni/s)
#   epoch 10: batch 2502/2781  value MSE parziale 0.6585  (1393 posizioni/s)
#   epoch 10: batch 2780/2781  value MSE parziale 0.6584  (1393 posizioni/s)
# epoch  10  train MSE 0.6584  train policy CE 2.9383  train loss 3.5967  val MSE 0.6867  val segno-ok 71.7% (su 72236 decisive)  val policy CE 2.8817  [salvato]
#   epoch 11: batch 278/2781  value MSE parziale 0.6573  (1406 posizioni/s)
#   epoch 11: batch 556/2781  value MSE parziale 0.6549  (1411 posizioni/s)
#   epoch 11: batch 834/2781  value MSE parziale 0.6554  (1415 posizioni/s)
#   epoch 11: batch 1112/2781  value MSE parziale 0.6553  (1413 posizioni/s)
#   epoch 11: batch 1390/2781  value MSE parziale 0.6543  (1412 posizioni/s)
#   epoch 11: batch 1668/2781  value MSE parziale 0.6549  (1412 posizioni/s)
#   epoch 11: batch 1946/2781  value MSE parziale 0.6547  (1412 posizioni/s)
#   epoch 11: batch 2224/2781  value MSE parziale 0.6549  (1414 posizioni/s)
#   epoch 11: batch 2502/2781  value MSE parziale 0.6546  (1415 posizioni/s)
#   epoch 11: batch 2780/2781  value MSE parziale 0.6549  (1400 posizioni/s)
# epoch  11  train MSE 0.6549  train policy CE 2.9316  train loss 3.5865  val MSE 0.6905  val segno-ok 71.4% (su 72236 decisive)  val policy CE 2.8745  [salvato]
#   epoch 12: batch 278/2781  value MSE parziale 0.6492  (1423 posizioni/s)
#   epoch 12: batch 556/2781  value MSE parziale 0.6500  (1416 posizioni/s)
#   epoch 12: batch 834/2781  value MSE parziale 0.6500  (1418 posizioni/s)
#   epoch 12: batch 1112/2781  value MSE parziale 0.6514  (1418 posizioni/s)
#   epoch 12: batch 1390/2781  value MSE parziale 0.6514  (1418 posizioni/s)
#   epoch 12: batch 1668/2781  value MSE parziale 0.6514  (1418 posizioni/s)
#   epoch 12: batch 1946/2781  value MSE parziale 0.6513  (1419 posizioni/s)
#   epoch 12: batch 2224/2781  value MSE parziale 0.6511  (1419 posizioni/s)
#   epoch 12: batch 2502/2781  value MSE parziale 0.6519  (1420 posizioni/s)
#   epoch 12: batch 2780/2781  value MSE parziale 0.6518  (1419 posizioni/s)
# epoch  12  train MSE 0.6518  train policy CE 2.9261  train loss 3.5779  val MSE 0.6873  val segno-ok 71.7% (su 72236 decisive)  val policy CE 2.8630  [salvato]
#   epoch 13: batch 278/2781  value MSE parziale 0.6488  (1415 posizioni/s)
#   epoch 13: batch 556/2781  value MSE parziale 0.6494  (1417 posizioni/s)
#   epoch 13: batch 834/2781  value MSE parziale 0.6500  (1417 posizioni/s)
#   epoch 13: batch 1112/2781  value MSE parziale 0.6494  (1417 posizioni/s)
#   epoch 13: batch 1390/2781  value MSE parziale 0.6490  (1419 posizioni/s)
#   epoch 13: batch 1668/2781  value MSE parziale 0.6502  (1418 posizioni/s)
#   epoch 13: batch 1946/2781  value MSE parziale 0.6498  (1414 posizioni/s)
#   epoch 13: batch 2224/2781  value MSE parziale 0.6500  (1412 posizioni/s)
#   epoch 13: batch 2502/2781  value MSE parziale 0.6494  (1412 posizioni/s)
#   epoch 13: batch 2780/2781  value MSE parziale 0.6494  (1415 posizioni/s)
# epoch  13  train MSE 0.6494  train policy CE 2.9228  train loss 3.5722  val MSE 0.6867  val segno-ok 71.6% (su 72236 decisive)  val policy CE 2.8683
#   epoch 14: batch 278/2781  value MSE parziale 0.6390  (1393 posizioni/s)
#   epoch 14: batch 556/2781  value MSE parziale 0.6401  (1409 posizioni/s)
#   epoch 14: batch 834/2781  value MSE parziale 0.6428  (1408 posizioni/s)
#   epoch 14: batch 1112/2781  value MSE parziale 0.6441  (1410 posizioni/s)
#   epoch 14: batch 1390/2781  value MSE parziale 0.6439  (1412 posizioni/s)
#   epoch 14: batch 1668/2781  value MSE parziale 0.6445  (1410 posizioni/s)
#   epoch 14: batch 1946/2781  value MSE parziale 0.6442  (1411 posizioni/s)
#   epoch 14: batch 2224/2781  value MSE parziale 0.6446  (1410 posizioni/s)
#   epoch 14: batch 2502/2781  value MSE parziale 0.6446  (1409 posizioni/s)
#   epoch 14: batch 2780/2781  value MSE parziale 0.6448  (1407 posizioni/s)
# epoch  14  train MSE 0.6448  train policy CE 2.9176  train loss 3.5625  val MSE 0.6909  val segno-ok 71.5% (su 72236 decisive)  val policy CE 2.8625
#   epoch 15: batch 278/2781  value MSE parziale 0.6400  (1387 posizioni/s)
#   epoch 15: batch 556/2781  value MSE parziale 0.6405  (1397 posizioni/s)
#   epoch 15: batch 834/2781  value MSE parziale 0.6416  (1403 posizioni/s)
#   epoch 15: batch 1112/2781  value MSE parziale 0.6415  (1404 posizioni/s)
#   epoch 15: batch 1390/2781  value MSE parziale 0.6407  (1403 posizioni/s)
#   epoch 15: batch 1668/2781  value MSE parziale 0.6416  (1394 posizioni/s)
#   epoch 15: batch 1946/2781  value MSE parziale 0.6414  (1390 posizioni/s)
#   epoch 15: batch 2224/2781  value MSE parziale 0.6422  (1389 posizioni/s)
#   epoch 15: batch 2502/2781  value MSE parziale 0.6423  (1389 posizioni/s)
#   epoch 15: batch 2780/2781  value MSE parziale 0.6424  (1390 posizioni/s)
# epoch  15  train MSE 0.6424  train policy CE 2.9150  train loss 3.5574  val MSE 0.6935  val segno-ok 71.4% (su 72236 decisive)  val policy CE 2.8648
#   epoch 16: batch 278/2781  value MSE parziale 0.6376  (1398 posizioni/s)
#   epoch 16: batch 556/2781  value MSE parziale 0.6389  (1406 posizioni/s)
#   epoch 16: batch 834/2781  value MSE parziale 0.6391  (1407 posizioni/s)
#   epoch 16: batch 1112/2781  value MSE parziale 0.6390  (1407 posizioni/s)
#   epoch 16: batch 1390/2781  value MSE parziale 0.6393  (1402 posizioni/s)
#   epoch 16: batch 1668/2781  value MSE parziale 0.6392  (1398 posizioni/s)
#   epoch 16: batch 1946/2781  value MSE parziale 0.6392  (1393 posizioni/s)
#   epoch 16: batch 2224/2781  value MSE parziale 0.6390  (1393 posizioni/s)
#   epoch 16: batch 2502/2781  value MSE parziale 0.6394  (1392 posizioni/s)
#   epoch 16: batch 2780/2781  value MSE parziale 0.6394  (1394 posizioni/s)
# epoch  16  train MSE 0.6394  train policy CE 2.9107  train loss 3.5501  val MSE 0.6889  val segno-ok 71.7% (su 72236 decisive)  val policy CE 2.8578  [salvato]
#   epoch 17: batch 278/2781  value MSE parziale 0.6370  (1403 posizioni/s)
#   epoch 17: batch 556/2781  value MSE parziale 0.6385  (1413 posizioni/s)
#   epoch 17: batch 834/2781  value MSE parziale 0.6360  (1410 posizioni/s)
#   epoch 17: batch 1112/2781  value MSE parziale 0.6367  (1403 posizioni/s)
#   epoch 17: batch 1390/2781  value MSE parziale 0.6374  (1396 posizioni/s)
#   epoch 17: batch 1668/2781  value MSE parziale 0.6373  (1395 posizioni/s)
#   epoch 17: batch 1946/2781  value MSE parziale 0.6367  (1393 posizioni/s)
#   epoch 17: batch 2224/2781  value MSE parziale 0.6366  (1393 posizioni/s)
#   epoch 17: batch 2502/2781  value MSE parziale 0.6368  (1394 posizioni/s)
#   epoch 17: batch 2780/2781  value MSE parziale 0.6367  (1392 posizioni/s)
# epoch  17  train MSE 0.6367  train policy CE 2.9075  train loss 3.5442  val MSE 0.6934  val segno-ok 71.5% (su 72236 decisive)  val policy CE 2.8537
#   epoch 18: batch 278/2781  value MSE parziale 0.6376  (1378 posizioni/s)
#   epoch 18: batch 556/2781  value MSE parziale 0.6340  (1384 posizioni/s)
#   epoch 18: batch 834/2781  value MSE parziale 0.6329  (1382 posizioni/s)
#   epoch 18: batch 1112/2781  value MSE parziale 0.6329  (1384 posizioni/s)
#   epoch 18: batch 1390/2781  value MSE parziale 0.6330  (1384 posizioni/s)
#   epoch 18: batch 1668/2781  value MSE parziale 0.6334  (1385 posizioni/s)
#   epoch 18: batch 1946/2781  value MSE parziale 0.6333  (1387 posizioni/s)
#   epoch 18: batch 2224/2781  value MSE parziale 0.6330  (1388 posizioni/s)
#   epoch 18: batch 2502/2781  value MSE parziale 0.6333  (1390 posizioni/s)
#   epoch 18: batch 2780/2781  value MSE parziale 0.6332  (1392 posizioni/s)
# epoch  18  train MSE 0.6332  train policy CE 2.9057  train loss 3.5388  val MSE 0.6911  val segno-ok 71.6% (su 72236 decisive)  val policy CE 2.8485  [salvato]
#   epoch 19: batch 278/2781  value MSE parziale 0.6303  (1399 posizioni/s)
#   epoch 19: batch 556/2781  value MSE parziale 0.6289  (1410 posizioni/s)
#   epoch 19: batch 834/2781  value MSE parziale 0.6295  (1410 posizioni/s)
#   epoch 19: batch 1112/2781  value MSE parziale 0.6306  (1411 posizioni/s)
#   epoch 19: batch 1390/2781  value MSE parziale 0.6303  (1414 posizioni/s)
#   epoch 19: batch 1668/2781  value MSE parziale 0.6303  (1415 posizioni/s)
#   epoch 19: batch 1946/2781  value MSE parziale 0.6306  (1414 posizioni/s)
#   epoch 19: batch 2224/2781  value MSE parziale 0.6309  (1412 posizioni/s)
#   epoch 19: batch 2502/2781  value MSE parziale 0.6307  (1409 posizioni/s)
#   epoch 19: batch 2780/2781  value MSE parziale 0.6308  (1407 posizioni/s)
# epoch  19  train MSE 0.6308  train policy CE 2.9015  train loss 3.5322  val MSE 0.6973  val segno-ok 71.3% (su 72236 decisive)  val policy CE 2.8437
#   epoch 20: batch 278/2781  value MSE parziale 0.6291  (1368 posizioni/s)
#   epoch 20: batch 556/2781  value MSE parziale 0.6291  (1377 posizioni/s)
#   epoch 20: batch 834/2781  value MSE parziale 0.6279  (1388 posizioni/s)
#   epoch 20: batch 1112/2781  value MSE parziale 0.6273  (1395 posizioni/s)
#   epoch 20: batch 1390/2781  value MSE parziale 0.6268  (1396 posizioni/s)
#   epoch 20: batch 1668/2781  value MSE parziale 0.6272  (1399 posizioni/s)
#   epoch 20: batch 1946/2781  value MSE parziale 0.6276  (1402 posizioni/s)
#   epoch 20: batch 2224/2781  value MSE parziale 0.6275  (1405 posizioni/s)
#   epoch 20: batch 2502/2781  value MSE parziale 0.6280  (1406 posizioni/s)
#   epoch 20: batch 2780/2781  value MSE parziale 0.6278  (1407 posizioni/s)
# epoch  20  train MSE 0.6278  train policy CE 2.8988  train loss 3.5266  val MSE 0.6913  val segno-ok 71.6% (su 72236 decisive)  val policy CE 2.8538
#   epoch 21: batch 278/2781  value MSE parziale 0.6215  (1421 posizioni/s)
#   epoch 21: batch 556/2781  value MSE parziale 0.6216  (1399 posizioni/s)
#   epoch 21: batch 834/2781  value MSE parziale 0.6216  (1395 posizioni/s)
#   epoch 21: batch 1112/2781  value MSE parziale 0.6224  (1401 posizioni/s)
#   epoch 21: batch 1390/2781  value MSE parziale 0.6236  (1406 posizioni/s)
#   epoch 21: batch 1668/2781  value MSE parziale 0.6244  (1408 posizioni/s)
#   epoch 21: batch 1946/2781  value MSE parziale 0.6243  (1408 posizioni/s)
#   epoch 21: batch 2224/2781  value MSE parziale 0.6252  (1411 posizioni/s)
#   epoch 21: batch 2502/2781  value MSE parziale 0.6252  (1412 posizioni/s)
#   epoch 21: batch 2780/2781  value MSE parziale 0.6250  (1414 posizioni/s)
# epoch  21  train MSE 0.6250  train policy CE 2.8983  train loss 3.5234  val MSE 0.6947  val segno-ok 71.4% (su 72236 decisive)  val policy CE 2.8499
#   epoch 22: batch 278/2781  value MSE parziale 0.6250  (1415 posizioni/s)
#   epoch 22: batch 556/2781  value MSE parziale 0.6224  (1414 posizioni/s)
#   epoch 22: batch 834/2781  value MSE parziale 0.6224  (1419 posizioni/s)
#   epoch 22: batch 1112/2781  value MSE parziale 0.6222  (1410 posizioni/s)
#   epoch 22: batch 1390/2781  value MSE parziale 0.6223  (1408 posizioni/s)
#   epoch 22: batch 1668/2781  value MSE parziale 0.6229  (1406 posizioni/s)
#   epoch 22: batch 1946/2781  value MSE parziale 0.6230  (1407 posizioni/s)
#   epoch 22: batch 2224/2781  value MSE parziale 0.6226  (1407 posizioni/s)
#   epoch 22: batch 2502/2781  value MSE parziale 0.6231  (1406 posizioni/s)
#   epoch 22: batch 2780/2781  value MSE parziale 0.6226  (1406 posizioni/s)
# epoch  22  train MSE 0.6226  train policy CE 2.8953  train loss 3.5179  val MSE 0.6986  val segno-ok 71.1% (su 72236 decisive)  val policy CE 2.8513
#   epoch 23: batch 278/2781  value MSE parziale 0.6182  (1404 posizioni/s)
#   epoch 23: batch 556/2781  value MSE parziale 0.6189  (1410 posizioni/s)
#   epoch 23: batch 834/2781  value MSE parziale 0.6190  (1406 posizioni/s)
#   epoch 23: batch 1112/2781  value MSE parziale 0.6197  (1405 posizioni/s)
#   epoch 23: batch 1390/2781  value MSE parziale 0.6194  (1408 posizioni/s)
#   epoch 23: batch 1668/2781  value MSE parziale 0.6195  (1413 posizioni/s)
#   epoch 23: batch 1946/2781  value MSE parziale 0.6194  (1415 posizioni/s)
#   epoch 23: batch 2224/2781  value MSE parziale 0.6190  (1418 posizioni/s)
#   epoch 23: batch 2502/2781  value MSE parziale 0.6197  (1419 posizioni/s)
#   epoch 23: batch 2780/2781  value MSE parziale 0.6195  (1419 posizioni/s)
# epoch  23  train MSE 0.6195  train policy CE 2.8931  train loss 3.5127  val MSE 0.6975  val segno-ok 71.4% (su 72236 decisive)  val policy CE 2.8456
#   epoch 24: batch 278/2781  value MSE parziale 0.6111  (1426 posizioni/s)
#   epoch 24: batch 556/2781  value MSE parziale 0.6140  (1415 posizioni/s)
#   epoch 24: batch 834/2781  value MSE parziale 0.6145  (1416 posizioni/s)
#   epoch 24: batch 1112/2781  value MSE parziale 0.6145  (1417 posizioni/s)
#   epoch 24: batch 1390/2781  value MSE parziale 0.6146  (1418 posizioni/s)
#   epoch 24: batch 1668/2781  value MSE parziale 0.6151  (1419 posizioni/s)
#   epoch 24: batch 1946/2781  value MSE parziale 0.6157  (1420 posizioni/s)
#   epoch 24: batch 2224/2781  value MSE parziale 0.6163  (1420 posizioni/s)
#   epoch 24: batch 2502/2781  value MSE parziale 0.6168  (1421 posizioni/s)
#   epoch 24: batch 2780/2781  value MSE parziale 0.6173  (1420 posizioni/s)
# epoch  24  train MSE 0.6173  train policy CE 2.8913  train loss 3.5086  val MSE 0.7002  val segno-ok 71.3% (su 72236 decisive)  val policy CE 2.8442
#   epoch 25: batch 278/2781  value MSE parziale 0.6112  (1422 posizioni/s)
#   epoch 25: batch 556/2781  value MSE parziale 0.6142  (1424 posizioni/s)
#   epoch 25: batch 834/2781  value MSE parziale 0.6155  (1422 posizioni/s)
#   epoch 25: batch 1112/2781  value MSE parziale 0.6150  (1421 posizioni/s)
#   epoch 25: batch 1390/2781  value MSE parziale 0.6148  (1419 posizioni/s)
#   epoch 25: batch 1668/2781  value MSE parziale 0.6153  (1417 posizioni/s)
#   epoch 25: batch 1946/2781  value MSE parziale 0.6154  (1416 posizioni/s)
#   epoch 25: batch 2224/2781  value MSE parziale 0.6155  (1415 posizioni/s)
#   epoch 25: batch 2502/2781  value MSE parziale 0.6155  (1416 posizioni/s)
#   epoch 25: batch 2780/2781  value MSE parziale 0.6149  (1417 posizioni/s)
# epoch  25  train MSE 0.6149  train policy CE 2.8906  train loss 3.5055  val MSE 0.7004  val segno-ok 71.1% (su 72236 decisive)  val policy CE 2.8464
#   epoch 26: batch 278/2781  value MSE parziale 0.6078  (1413 posizioni/s)
#   epoch 26: batch 556/2781  value MSE parziale 0.6102  (1420 posizioni/s)
#   epoch 26: batch 834/2781  value MSE parziale 0.6091  (1403 posizioni/s)
#   epoch 26: batch 1112/2781  value MSE parziale 0.6099  (1406 posizioni/s)
#   epoch 26: batch 1390/2781  value MSE parziale 0.6098  (1404 posizioni/s)
#   epoch 26: batch 1668/2781  value MSE parziale 0.6101  (1399 posizioni/s)
#   epoch 26: batch 1946/2781  value MSE parziale 0.6106  (1402 posizioni/s)
#   epoch 26: batch 2224/2781  value MSE parziale 0.6109  (1403 posizioni/s)
#   epoch 26: batch 2502/2781  value MSE parziale 0.6120  (1404 posizioni/s)
#   epoch 26: batch 2780/2781  value MSE parziale 0.6118  (1403 posizioni/s)
# epoch  26  train MSE 0.6118  train policy CE 2.8880  train loss 3.4998  val MSE 0.7000  val segno-ok 71.3% (su 72236 decisive)  val policy CE 2.8477
#   epoch 27: batch 278/2781  value MSE parziale 0.6072  (1404 posizioni/s)
#   epoch 27: batch 556/2781  value MSE parziale 0.6062  (1395 posizioni/s)
#   epoch 27: batch 834/2781  value MSE parziale 0.6069  (1397 posizioni/s)
#   epoch 27: batch 1112/2781  value MSE parziale 0.6078  (1390 posizioni/s)
#   epoch 27: batch 1390/2781  value MSE parziale 0.6078  (1387 posizioni/s)
#   epoch 27: batch 1668/2781  value MSE parziale 0.6085  (1389 posizioni/s)
#   epoch 27: batch 1946/2781  value MSE parziale 0.6093  (1387 posizioni/s)
#   epoch 27: batch 2224/2781  value MSE parziale 0.6093  (1389 posizioni/s)
#   epoch 27: batch 2502/2781  value MSE parziale 0.6093  (1392 posizioni/s)
#   epoch 27: batch 2780/2781  value MSE parziale 0.6098  (1395 posizioni/s)
# epoch  27  train MSE 0.6098  train policy CE 2.8870  train loss 3.4967  val MSE 0.7086  val segno-ok 71.0% (su 72236 decisive)  val policy CE 2.8434
#   epoch 28: batch 278/2781  value MSE parziale 0.6050  (1407 posizioni/s)
#   epoch 28: batch 556/2781  value MSE parziale 0.6051  (1412 posizioni/s)
#   epoch 28: batch 834/2781  value MSE parziale 0.6066  (1411 posizioni/s)
#   epoch 28: batch 1112/2781  value MSE parziale 0.6059  (1408 posizioni/s)
#   epoch 28: batch 1390/2781  value MSE parziale 0.6066  (1408 posizioni/s)
#   epoch 28: batch 1668/2781  value MSE parziale 0.6072  (1406 posizioni/s)
#   epoch 28: batch 1946/2781  value MSE parziale 0.6081  (1409 posizioni/s)
#   epoch 28: batch 2224/2781  value MSE parziale 0.6079  (1408 posizioni/s)
#   epoch 28: batch 2502/2781  value MSE parziale 0.6077  (1410 posizioni/s)
#   epoch 28: batch 2780/2781  value MSE parziale 0.6081  (1410 posizioni/s)
# epoch  28  train MSE 0.6081  train policy CE 2.8860  train loss 3.4941  val MSE 0.7072  val segno-ok 71.0% (su 72236 decisive)  val policy CE 2.8362
#   epoch 29: batch 278/2781  value MSE parziale 0.6061  (1391 posizioni/s)
#   epoch 29: batch 556/2781  value MSE parziale 0.6050  (1389 posizioni/s)
#   epoch 29: batch 834/2781  value MSE parziale 0.6042  (1391 posizioni/s)
#   epoch 29: batch 1112/2781  value MSE parziale 0.6048  (1391 posizioni/s)
#   epoch 29: batch 1390/2781  value MSE parziale 0.6044  (1392 posizioni/s)
#   epoch 29: batch 1668/2781  value MSE parziale 0.6047  (1395 posizioni/s)
#   epoch 29: batch 1946/2781  value MSE parziale 0.6046  (1395 posizioni/s)
#   epoch 29: batch 2224/2781  value MSE parziale 0.6045  (1398 posizioni/s)
#   epoch 29: batch 2502/2781  value MSE parziale 0.6047  (1400 posizioni/s)
#   epoch 29: batch 2780/2781  value MSE parziale 0.6050  (1402 posizioni/s)
# epoch  29  train MSE 0.6050  train policy CE 2.8848  train loss 3.4898  val MSE 0.7157  val segno-ok 70.6% (su 72236 decisive)  val policy CE 2.8469
#   epoch 30: batch 278/2781  value MSE parziale 0.6002  (1382 posizioni/s)
#   epoch 30: batch 556/2781  value MSE parziale 0.5997  (1391 posizioni/s)
#   epoch 30: batch 834/2781  value MSE parziale 0.6007  (1394 posizioni/s)
#   epoch 30: batch 1112/2781  value MSE parziale 0.5999  (1393 posizioni/s)
#   epoch 30: batch 1390/2781  value MSE parziale 0.6010  (1392 posizioni/s)
#   epoch 30: batch 1668/2781  value MSE parziale 0.6013  (1392 posizioni/s)
#   epoch 30: batch 1946/2781  value MSE parziale 0.6015  (1392 posizioni/s)
#   epoch 30: batch 2224/2781  value MSE parziale 0.6022  (1393 posizioni/s)
#   epoch 30: batch 2502/2781  value MSE parziale 0.6020  (1396 posizioni/s)
#   epoch 30: batch 2780/2781  value MSE parziale 0.6029  (1397 posizioni/s)
# epoch  30  train MSE 0.6029  train policy CE 2.8826  train loss 3.4855  val MSE 0.7052  val segno-ok 71.3% (su 72236 decisive)  val policy CE 2.8370
#
# Checkpoint migliore salvato in: /kaggle/working/checkpoint_gen0_policy.pt (MSE 3.5396)
# Per esportarlo per il C++:
#   python3 scripts/export_hive_value_gnn.py --weights /kaggle/working/checkpoint_gen0_policy.pt --output hive_value_gnn.pt

# %% [markdown]
# ### Dopo il training
#
# Il checkpoint migliore è in `/kaggle/working/checkpoint_gen0_policy.pt`: si
# scarica dal file browser del pannello di destra (sessione interattiva) o
# dalla scheda *Output* del notebook (dopo *Save & Run All*). Conviene anche
# caricarlo nella cartella Drive `HiveGotThis_colab/`, dove stanno gli altri
# checkpoint. In locale:
#
# ```bash
# # esporta per il C++ (ambiente locale con torch_geometric==2.6.1)
# python3 scripts/export_hive_value_gnn.py --weights checkpoint_gen0_policy.pt --output hive_policy_gen0.pt
#
# # il motore la usa (l'MCTS rileva la policy head e passa a PUCT da solo)
# ./build/HiveEngine hive_policy_gen0.pt
# ```
#
# I passi successivi sono il benchmark del costo PUCT (la policy aggiunge una
# chiamata alla rete per espansione) e il match dell'harness contro la gen-0
# value-only: stesso match, stesse condizioni, un modello per lato
# (`tools/uhp_match.py`, doc §8).
